# %%
from selenium import webdriver
from bs4 import BeautifulSoup as s
import pandas as pd

# %%
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome('chromedriver')

# %%
data=[] #List to store rating of the product
driver.get("https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.brand%255B%255D%3DRealme&otracker=clp_metro_expandable_1_3.metroExpandable.METRO_EXPANDABLE_realme_mobile-phones-store_0JN61DYS7W5I_wp3&fm=neo%2Fmerchandising&iid=M_6409adb1-2338-46bc-86ee-17f781ae7ae6_3.0JN61DYS7W5I&ssid=bfqes70tsw0000001623891409491")

# %%
import numpy as np
pages=np.arange(1,11,1)
from time import sleep
from random import randint

# %%
for page in pages:
    
    page="https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.brand%255B%255D%3DRealme&otracker=clp_metro_expandable_1_3.metroExpandable.METRO_EXPANDABLE_realme_mobile-phones-store_0JN61DYS7W5I_wp3&fm=neo%2Fmerchandising&iid=M_6409adb1-2338-46bc-86ee-17f781ae7ae6_3.0JN61DYS7W5I&ssid=bfqes70tsw0000001623891409491&page=" + str(page) 
    driver = webdriver.Chrome()
    driver.get(page)  
    sleep(randint(2,10))
    soup = s(driver.page_source, 'html.parser')
    my_table = soup.find_all(class_=['_4rR01T', '_3LWZ1K','_1xgFaf','_30jeq3 _1_WHN1'])
    for tag in my_table:
        data.append(tag.get_text())

# %%
data
# Out:
# ['realme C20 (Cool Blue, 32 GB)',
#  '2 GB RAM | 32 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) HD+ Display8MP Rear Camera | 5MP Front Camera5000 mAh BatteryMediaTek Helio G35 Processor1 Year Warranty for Mobile and 6 Months for Accessories',
#  '₹6,799',
#  'realme C20 (Cool Grey, 32 GB)',
#  '2 GB RAM | 32 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) HD+ Display8MP Rear Camera | 5MP Front Camera5000 mAh BatteryMediaTek Helio G35 Processor1 Year Warranty for Mobile and 6 Months for Accessories',
#  '₹6,799',
#  'realme C21 (Cross Blue, 64 GB)',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) HD+ Display13MP + 2MP + 2MP | 5MP Front Camera5000 mAh BatteryMediaTek Helio G35 Processor1 Year Warranty for Mobile and 6 Months for Accessories',
#  '₹8,999',
#  'realme C21 (Cross Black, 32 GB)',
# ...

# %%
len(data)
# Out:
# 672

# %%
names=[]
desc=[]
price=[]
for i in range(672):
    if i%3==0:
        name.append(data[i])
    elif i%3==1:
        desc.append(data[i])
    else:
        price.append(data[i])

# %%
name
# Out:
# ['realme C20 (Cool Blue, 32 GB)',
#  'realme C20 (Cool Grey, 32 GB)',
#  'realme C21 (Cross Blue, 64 GB)',
#  'realme C21 (Cross Black, 32 GB)',
#  'realme C21 (Cross Black, 64 GB)',
#  'realme Narzo 30A (Laser Black, 32 GB)',
#  'realme Narzo 30A (Laser Blue, 64 GB)',
#  'realme Narzo 30A (Laser Blue, 32 GB)',
#  'realme Narzo 30A (Laser Black, 64 GB)',
#  'realme 8 5G (Supersonic Blue, 64 GB)',
#  'realme 8 5G (Supersonic Black, 64 GB)',
#  'realme C12 (Power Silver, 32 GB)',
#  'realme C25 (Watery Blue, 64 GB)',
#  'realme Narzo 20 (Victory Blue, 64 GB)',
#  'realme C12 (Power Blue, 32 GB)',
#  'realme C25s (Watery Grey, 128 GB)',
#  'realme C15 Qualcomm Edition (Power Blue, 64 GB)',
#  'realme C15 Qualcomm Edition (Power Silver, 64 GB)',
#  'realme C25 (Watery Blue, 128 GB)',
#  'realme C25 (Watery Grey, 128 GB)',
#  'realme Narzo 20 (Glory Silver, 64 GB)',
#  'realme 8 5G (Supersonic Blue, 128 GB)',
#  'realme 8 5G (Supersonic Black, 128 GB)',
# ...

# %%
price
# Out:
# ['₹6,799',
#  '₹6,799',
#  '₹8,999',
#  '₹7,999',
#  '₹8,999',
#  '₹8,249',
#  '₹9,999',
#  '₹8,249',
#  '₹9,999',
#  '₹13,999',
#  '₹13,999',
#  '₹8,999',
#  '₹9,999',
#  '₹10,499',
#  '₹8,999',
#  '₹11,499',
#  '₹9,999',
#  '₹9,999',
#  '₹10,999',
#  '₹10,999',
#  '₹10,499',
#  '₹16,999',
#  '₹16,999',
#  '₹14,999',
#  '₹14,999',
#  '₹11,499',
#  '₹8,999',
#  '₹8,999',
#  '₹10,499',
#  '₹10,499',
#  '₹9,999',
#  '₹15,999',
#  '₹14,999',
#  '₹14,999',
#  '₹13,999',
#  '₹11,499',
#  '₹11,499',
#  '₹14,999',
#  '₹14,999',
#  '₹13,999',
#  '₹15,999',
#  '₹19,999',
#  '₹7,499',
#  '₹7,499',
#  '₹17,999',
#  '₹19,999',
#  '₹17,999',
#  '₹17,999',
#  '₹17,999',
#  '₹19,999',
#  '₹8,999',
#  '₹17,999',
#  '₹17,999',
#  '₹17,999',
#  '₹19,999',
#  '₹19,999',
#  '₹17,999',
#  '₹15,999',
#  '₹17,999',
#  '₹8,499',
#  '₹15,999',
#  '₹17,999',
#  '₹26,999',
#  '₹8,499',
#  '₹10,499',
#  '₹14,999',
#  '₹16,999',
#  '₹14,999',
#  '₹10,499',
#  '₹23,999',
#  '₹8,999',
#  '₹26,999',
#  '₹29,999',
# ...

# %%
desc
# Out:
# ['2 GB RAM | 32 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) HD+ Display8MP Rear Camera | 5MP Front Camera5000 mAh BatteryMediaTek Helio G35 Processor1 Year Warranty for Mobile and 6 Months for Accessories',
#  '2 GB RAM | 32 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) HD+ Display8MP Rear Camera | 5MP Front Camera5000 mAh BatteryMediaTek Helio G35 Processor1 Year Warranty for Mobile and 6 Months for Accessories',
#  '4 GB RAM | 64 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) HD+ Display13MP + 2MP + 2MP | 5MP Front Camera5000 mAh BatteryMediaTek Helio G35 Processor1 Year Warranty for Mobile and 6 Months for Accessories',
#  '3 GB RAM | 32 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) HD+ Display13MP + 2MP + 2MP | 5MP Front Camera5000 mAh BatteryMediaTek Helio G35 Processor1 Year Warranty for Mobile and 6 Months for Accessories',
# ...

# %%
d={"product":name,"description":desc,"price":price}
df=pd.DataFrame(d)

# %%
df
# Out:
#                                                product  \
# 0                        realme C20 (Cool Blue, 32 GB)
# 1                        realme C20 (Cool Grey, 32 GB)
# 2                       realme C21 (Cross Blue, 64 GB)
# 3                      realme C21 (Cross Black, 32 GB)
# 4                      realme C21 (Cross Black, 64 GB)
# ..                                                 ...
# 219                           realme 1 (Silver, 64 GB)
# 220                  realme 1 (Red, Solar Red, 128 GB)
# 221                    realme C2 (Diamond Blue, 32 GB)
# 222  Certified Refurbished Realme C2 (Test) (Diamon...
# 223  Certified Refurbished Realme C2 (Test) (Diamon...
#
#                                            description    price
# 0    2 GB RAM | 32 GB ROM | Expandable Upto 256 GB1...   ₹6,799
# 1    2 GB RAM | 32 GB ROM | Expandable Upto 256 GB1...   ₹6,799
# 2    4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...   ₹8,999
# ...
